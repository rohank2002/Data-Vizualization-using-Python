# %% [markdown]
# Lecture 14 Series

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
obj =Series([3,6,7,8,9])

# %%
obj
# Out:
# 0    3
# 1    6
# 2    7
# 3    8
# 4    9
# dtype: int64

# %%
obj.values
# Out:
# array([3, 6, 7, 8, 9], dtype=int64)

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
ww2_cas = Series([8700000,4300000,3000000,2100000,400000],index=['USSR','Germany','China','Japan','USA'])
ww2_cas
# Out:
# USSR       8700000
# Germany    4300000
# China      3000000
# Japan      2100000
# USA         400000
# dtype: int64

# %%
ww2_cas["USA"]
# Out:
# 400000

# %%
ww2_cas["USSR"]
# Out:
# 8700000

# %%
#Get Casualties greater than 4Million

# %%
ww2_cas[ww2_cas>4000000]
# Out:
# USSR       8700000
# Germany    4300000
# dtype: int64

# %%
"USSR" in ww2_cas
# Out:
# True

# %%
8700000 in ww2_cas
# Out:
# False

# %%
ww2_dict = ww2_cas.to_dict()  #Series to dictionary

# %%
ww2_dict
# Out:
# {'USSR': 8700000,
#  'Germany': 4300000,
#  'China': 3000000,
#  'Japan': 2100000,
#  'USA': 400000}

# %%
countries = ['China','Germany','Japan','USA','USSR','Argentina']
obj2=Series(ww2_cas,countries)

# %%
obj2
# Out:
# China        3000000.0
# Germany      4300000.0
# Japan        2100000.0
# USA           400000.0
# USSR         8700000.0
# Argentina          NaN
# dtype: float64

# %%
pd.isnull(obj2)                       #Check Null Values in Series
# Out:
# China        False
# Germany      False
# Japan        False
# USA          False
# USSR         False
# Argentina     True
# dtype: bool

# %%
pd.notnull(obj2)                      #Check Not Null values
# Out:
# China         True
# Germany       True
# Japan         True
# USA           True
# USSR          True
# Argentina    False
# dtype: bool

# %%
ww2_cas+obj2                        #Add 2 Series
# Out:
# Argentina           NaN
# China         6000000.0
# Germany       8600000.0
# Japan         4200000.0
# USA            800000.0
# USSR         17400000.0
# dtype: float64

# %%
obj2.name="World War 2 Series"

# %%
obj2
# Out:
# China        3000000.0
# Germany      4300000.0
# Japan        2100000.0
# USA           400000.0
# USSR         8700000.0
# Argentina          NaN
# Name: World War 2 Series, dtype: float64

# %%
obj2.index.name="Countries"

# %%
obj2
# Out:
# Countries
# China        3000000.0
# Germany      4300000.0
# Japan        2100000.0
# USA           400000.0
# USSR         8700000.0
# Argentina          NaN
# Name: World War 2 Series, dtype: float64

# %% [markdown]
# Lecture 15 DataFrames

# %%
import webbrowser
websites='http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(websites)
# Out:
# True

# %%
nfl_frame=pd.read_clipboard()    # Copy from ClipBoard into a DataFrame

# %%
nfl_frame
# Out:
#     Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0      1           Dallas Cowboys    882  502   374     6  0.573
# 1      2        Green Bay Packers  1,336  737   562    37  0.565
# 2      3            Chicago Bears  1,370  749   579    42  0.562
# 3      4           Miami Dolphins    800  445   351     4  0.559
# 4      5  New England Patriots[b]    884  489   386     9  0.558
# 5      6        Minnesota Vikings    870  470   390    10  0.546
# 6      7         Baltimore Ravens    352  190   161     1  0.541
# 7      8          New York Giants  1,305  687   585    33  0.539
# 8      9           Denver Broncos    884  470   404    10  0.537
# 9     10      San Francisco 49ers  1,002  528   460    14  0.534
# 10    11      Pittsburgh Steelers  1,179  614   538    20  0.532
# 11    12          Oakland Raiders    884  462   411    11  0.529
# 12    13    Indianapolis Colts[c]    966  506   453     7  0.527
# ...

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame["First NFL Season"] #Column Name Has More Than One Word
# Out:
# 0     1960
# 1     1921
# 2     1920
# 3     1966
# 4     1960
# 5     1961
# 6     1996
# 7     1925
# 8     1960
# 9     1950
# 10    1933
# 11    1960
# 12    1953
# 13    1960
# 14    1976
# 15    1932
# 16    1995
# 17    1960
# 18    1937
# 19    1950
# 20    1933
# 21    1960
# 22    1960
# 23    1930
# 24    1968
# 25    1960
# 26    1995
# 27    1967
# 28    1966
# 29    2002
# 30    1920
# 31    1976
# Name: First NFL Season, dtype: int64

# %%
DataFrame(nfl_frame,columns=['Rank', 'Team', 'GP', 'Won', 'Lost'])
# Out:
#     Rank                     Team     GP  Won  Lost
# 0      1           Dallas Cowboys    882  502   374
# 1      2        Green Bay Packers  1,336  737   562
# 2      3            Chicago Bears  1,370  749   579
# 3      4           Miami Dolphins    800  445   351
# 4      5  New England Patriots[b]    884  489   386
# 5      6        Minnesota Vikings    870  470   390
# 6      7         Baltimore Ravens    352  190   161
# 7      8          New York Giants  1,305  687   585
# 8      9           Denver Broncos    884  470   404
# 9     10      San Francisco 49ers  1,002  528   460
# 10    11      Pittsburgh Steelers  1,179  614   538
# 11    12          Oakland Raiders    884  462   411
# 12    13    Indianapolis Colts[c]    966  506   453
# 13    14       Kansas City Chiefs    884  457   415
# 14    15         Seattle Seahawks    660  334   325
# 15    16      Washington Redskins  1,202  595   581
# 16    17        Carolina Panthers    368  183   184
# ...

# %%
nfl_frame.head(3)
# Out:
#    Rank               Team     GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1     Dallas Cowboys    882  502   374     6  0.573              1960
# 1     2  Green Bay Packers  1,336  737   562    37  0.565              1921
# 2     3      Chicago Bears  1,370  749   579    42  0.562              1920
#
#     Division
# 0   NFC East
# 1  NFC North
# 2  NFC North

# %%
nfl_frame.tail(3)
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 29    30        Houston Texans    256  110   146     0  0.430
# 30    31     Arizona Cardinals  1,330  550   740    40  0.429
# 31    32  Tampa Bay Buccaneers    660  255   404     1  0.387
#
#     First NFL Season   Division
# 29              2002  AFC South
# 30              1920   NFC West
# 31              1976  NFC South

# %%
nfl_frame.ix[3]
# Out:
# C:\Users\kamat\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Rank                             4
# Team                Miami Dolphins
# GP                             800
# Won                            445
# Lost                           351
# Tied                             4
# Pct.                         0.559
# First NFL Season              1966
# Division                  AFC East
# Name: 3, dtype: object

# %%
nfl_frame['Stadium']="Levi's Stadium"

# %%
nfl_frame
# Out:
#     Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0      1           Dallas Cowboys    882  502   374     6  0.573
# 1      2        Green Bay Packers  1,336  737   562    37  0.565
# 2      3            Chicago Bears  1,370  749   579    42  0.562
# 3      4           Miami Dolphins    800  445   351     4  0.559
# 4      5  New England Patriots[b]    884  489   386     9  0.558
# 5      6        Minnesota Vikings    870  470   390    10  0.546
# 6      7         Baltimore Ravens    352  190   161     1  0.541
# 7      8          New York Giants  1,305  687   585    33  0.539
# 8      9           Denver Broncos    884  470   404    10  0.537
# 9     10      San Francisco 49ers  1,002  528   460    14  0.534
# 10    11      Pittsburgh Steelers  1,179  614   538    20  0.532
# 11    12          Oakland Raiders    884  462   411    11  0.529
# 12    13    Indianapolis Colts[c]    966  506   453     7  0.527
# ...

# %%
nfl_frame["Stadium"]=np.arange(32)

# %%
nfl_frame
# Out:
#     Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0      1           Dallas Cowboys    882  502   374     6  0.573
# 1      2        Green Bay Packers  1,336  737   562    37  0.565
# 2      3            Chicago Bears  1,370  749   579    42  0.562
# 3      4           Miami Dolphins    800  445   351     4  0.559
# 4      5  New England Patriots[b]    884  489   386     9  0.558
# 5      6        Minnesota Vikings    870  470   390    10  0.546
# 6      7         Baltimore Ravens    352  190   161     1  0.541
# 7      8          New York Giants  1,305  687   585    33  0.539
# 8      9           Denver Broncos    884  470   404    10  0.537
# 9     10      San Francisco 49ers  1,002  528   460    14  0.534
# 10    11      Pittsburgh Steelers  1,179  614   538    20  0.532
# 11    12          Oakland Raiders    884  462   411    11  0.529
# 12    13    Indianapolis Colts[c]    966  506   453     7  0.527
# ...

# %%
# Add Series to a data frame

# %%
 stadiums = Series(["Levi's Stadium","AT&T Stadium"],index=[4,0])

# %%
nfl_frame["Stadium"]=stadiums

# %%
nfl_frame
# Out:
#     Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0      1           Dallas Cowboys    882  502   374     6  0.573
# 1      2        Green Bay Packers  1,336  737   562    37  0.565
# 2      3            Chicago Bears  1,370  749   579    42  0.562
# 3      4           Miami Dolphins    800  445   351     4  0.559
# 4      5  New England Patriots[b]    884  489   386     9  0.558
# 5      6        Minnesota Vikings    870  470   390    10  0.546
# 6      7         Baltimore Ravens    352  190   161     1  0.541
# 7      8          New York Giants  1,305  687   585    33  0.539
# 8      9           Denver Broncos    884  470   404    10  0.537
# 9     10      San Francisco 49ers  1,002  528   460    14  0.534
# 10    11      Pittsburgh Steelers  1,179  614   538    20  0.532
# 11    12          Oakland Raiders    884  462   411    11  0.529
# 12    13    Indianapolis Colts[c]    966  506   453     7  0.527
# ...

# %%
del nfl_frame["Stadium"]     # Delete Stadium column

# %%
nfl_frame
# Out:
#     Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0      1           Dallas Cowboys    882  502   374     6  0.573
# 1      2        Green Bay Packers  1,336  737   562    37  0.565
# 2      3            Chicago Bears  1,370  749   579    42  0.562
# 3      4           Miami Dolphins    800  445   351     4  0.559
# 4      5  New England Patriots[b]    884  489   386     9  0.558
# 5      6        Minnesota Vikings    870  470   390    10  0.546
# 6      7         Baltimore Ravens    352  190   161     1  0.541
# 7      8          New York Giants  1,305  687   585    33  0.539
# 8      9           Denver Broncos    884  470   404    10  0.537
# 9     10      San Francisco 49ers  1,002  528   460    14  0.534
# 10    11      Pittsburgh Steelers  1,179  614   538    20  0.532
# 11    12          Oakland Raiders    884  462   411    11  0.529
# 12    13    Indianapolis Colts[c]    966  506   453     7  0.527
# ...

# %%
data = {'City':['SF','LA','NYC'],
        'Population':[837000,3880000,8400000]}

# %%
city_frame = DataFrame(data)

#Show
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000

# %%
#For full list of ways to create DataFrames from various sources go to teh documentation for pandas:
website = 'http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.html'
webbrowser.open(website)
# Out:
# True
